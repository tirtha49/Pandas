# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name":['Sachin Tendulkar', 'Virat Kohli', 'MS Dhoni', 'Rohit Sharma', 'Pat Cummins',
            'Ben Stokes', 'AB De Villiers', 'Steve Smith', 'Jasprit Bumrah', 'Hardik Pandya'],
    "Jersey": [10,18,7,45,30,55,17,49,93,33],
    "Country": ['India', 'India', 'India', 'India', 'Australia', 'England', 'South Africa',
                'Australia', 'India', 'India'],
    "Matches":[664,550,538,499,218,272,420,354,211,224],
    "Highest Score":[248,254,224,264,64,258,278,239,34,108]
})

# %%
print(df)
# Out:
#                Name  Jersey       Country  Matches  Highest Score
# 0  Sachin Tendulkar      10         India      664            248
# 1       Virat Kohli      18         India      550            254
# 2          MS Dhoni       7         India      538            224
# 3      Rohit Sharma      45         India      499            264
# 4       Pat Cummins      30     Australia      218             64
# 5        Ben Stokes      55       England      272            258
# 6    AB De Villiers      17  South Africa      420            278
# 7       Steve Smith      49     Australia      354            239
# 8    Jasprit Bumrah      93         India      211             34
# 9     Hardik Pandya      33         India      224            108

# %%
# First 5 elements
df.head()
# Out:
#                Name  Jersey    Country  Matches  Highest Score
# 0  Sachin Tendulkar      10      India      664            248
# 1       Virat Kohli      18      India      550            254
# 2          MS Dhoni       7      India      538            224
# 3      Rohit Sharma      45      India      499            264
# 4       Pat Cummins      30  Australia      218             64

# %%
# Last 5 elements
df.tail()
# Out:
#              Name  Jersey       Country  Matches  Highest Score
# 5      Ben Stokes      55       England      272            258
# 6  AB De Villiers      17  South Africa      420            278
# 7     Steve Smith      49     Australia      354            239
# 8  Jasprit Bumrah      93         India      211             34
# 9   Hardik Pandya      33         India      224            108

# %%
# Random 5 elemets
df.sample(5)
# Out:
#                Name  Jersey    Country  Matches  Highest Score
# 0  Sachin Tendulkar      10      India      664            248
# 5        Ben Stokes      55    England      272            258
# 1       Virat Kohli      18      India      550            254
# 7       Steve Smith      49  Australia      354            239
# 2          MS Dhoni       7      India      538            224

# %%
# Matrix data
df.ndim
# Out:
# 2

# %%
# (row,col)
df.shape
# Out:
# (10, 5)

# %%
# total elemetns
df.size
# Out:
# 50

# %%
# extract all column names
df.columns
# Out:
# Index(['Name', 'Jersey', 'Country', 'Matches', 'Highest Score'], dtype='object')

# %%
# find out all column type
df.dtypes
# Out:
# Name             object
# Jersey            int64
# Country          object
# Matches           int64
# Highest Score     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           10 non-null     object
#  1   Jersey         10 non-null     int64
#  2   Country        10 non-null     object
#  3   Matches        10 non-null     int64
#  4   Highest Score  10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#           Jersey     Matches  Highest Score
# count  10.000000   10.000000      10.000000
# mean   35.700000  395.000000     197.100000
# std    26.047179  163.133211      91.465172
# min     7.000000  211.000000      34.000000
# 25%    17.250000  236.000000     137.000000
# 50%    31.500000  387.000000     243.500000
# 75%    48.000000  528.250000     257.000000
# max    93.000000  664.000000     278.000000

# %%
# Selecting 1 or multiple(label_based) columns

# %%
df[["Name","Matches"]]
# Out:
#                Name  Matches
# 0  Sachin Tendulkar      664
# 1       Virat Kohli      550
# 2          MS Dhoni      538
# 3      Rohit Sharma      499
# 4       Pat Cummins      218
# 5        Ben Stokes      272
# 6    AB De Villiers      420
# 7       Steve Smith      354
# 8    Jasprit Bumrah      211
# 9     Hardik Pandya      224

# %%
df.filter(["Name","Matches"])
# Out:
#                Name  Matches
# 0  Sachin Tendulkar      664
# 1       Virat Kohli      550
# 2          MS Dhoni      538
# 3      Rohit Sharma      499
# 4       Pat Cummins      218
# 5        Ben Stokes      272
# 6    AB De Villiers      420
# 7       Steve Smith      354
# 8    Jasprit Bumrah      211
# 9     Hardik Pandya      224

# %%
# Selecting Index_based rows

# %%
# df.fliter[] ✅ & df.loc[] ✅

# %%
df.filter([0, 2], axis=0)
# Out:
#                Name  Jersey Country  Matches  Highest Score
# 0  Sachin Tendulkar      10   India      664            248
# 2          MS Dhoni       7   India      538            224

# %%
df.filter([2], axis=0)
# Out:
#        Name  Jersey Country  Matches  Highest Score
# 2  MS Dhoni       7   India      538            224

# %%
df.loc[2]
# Out:
# Name             MS Dhoni
# Jersey                  7
# Country             India
# Matches               538
# Highest Score         224
# Name: 2, dtype: object

# %%
# Extracting and Modifying elements from table (knowing row_idx, col_label)
# df.loc[] ✅ & df.at[] ✅

# %%
df.at[0,"Name"]
# Out:
# 'Sachin Tendulkar'

# %%
df.loc[2,"Name"]
# Out:
# 'MS Dhoni'

# %%
df.at[0,'Name'] = 'GOD of Cricket'

# %%
df.loc[2,"Name"]="Mahendra Singh Dhoni"

# %%
# Selecting a entire particular col with loc // (df["col_name"]✅) (df.filter(["col_name"])✅)
# df.loc[] is label based indexing
# expects row no. always
df.loc[:, "Jersey"]
# Out:
# 0    10
# 1    18
# 2     7
# 3    45
# 4    30
# 5    55
# 6    17
# 7    49
# 8    93
# 9    33
# Name: Jersey, dtype: int64

# %%
df["Name"]
# Out:
# 0          GOD of Cricket
# 1             Virat Kohli
# 2    Mahendra Singh Dhoni
# 3            Rohit Sharma
# 4             Pat Cummins
# 5              Ben Stokes
# 6          AB De Villiers
# 7             Steve Smith
# 8          Jasprit Bumrah
# 9           Hardik Pandya
# Name: Name, dtype: object

# %%
df.filter(["Name"])
# Out:
#                    Name
# 0        GOD of Cricket
# 1           Virat Kohli
# 2  Mahendra Singh Dhoni
# 3          Rohit Sharma
# 4           Pat Cummins
# 5            Ben Stokes
# 6        AB De Villiers
# 7           Steve Smith
# 8        Jasprit Bumrah
# 9         Hardik Pandya

# %%
# df.loc[] is label based whereas
# df.ioc[] is indexed based

# %%
# Slicing can not be done in df.loc[]

# %%
print(df.loc[0])                        # Select row with label 0 (0 is the label, not index)
print("--------------------------------------")
print(df.loc[0, 'Name'])                # Value from row 'a' and column 'Name'
print("--------------------------------------")
print(df.loc[:, 'Name'] )               # All rows, only 'Name' column
print("--------------------------------------")
print(df.loc[0:5, ['Name','Jersey']])   # Rows from 'a' to 'b', only Name & City)
# Out:
# Name             Sachin Tendulkar
# Jersey                         10
# Country                     India
# Matches                       664
# Highest Score                 248
# Name: 0, dtype: object
# --------------------------------------
# Sachin Tendulkar
# --------------------------------------
# 0    Sachin Tendulkar
# 1         Virat Kohli
# 2            MS Dhoni
# 3        Rohit Sharma
# 6      AB De Villiers
# 7         Steve Smith
# 5          Ben Stokes
# 9       Hardik Pandya
# 4         Pat Cummins
# 8      Jasprit Bumrah
# Name: Name, dtype: object
# --------------------------------------
#                Name  Jersey
# 0  Sachin Tendulkar      10
# 1       Virat Kohli      18
# 2          MS Dhoni       7
# 3      Rohit Sharma      45
# 6    AB De Villiers      17
# 7       Steve Smith      49
# 5        Ben Stokes      55

# %%
# df.at[] vs df.iat[]

# %% [markdown]
# ![Screenshot 2025-10-14 223443.png](data:image/png;base64,...)

# %%
df.at[0,"Name"]
# Out:
# 'GOD of Cricket'

# %%
df.iat[0,0]
# Out:
# 'GOD of Cricket'

# %%
# Modifying when row_idx & col_idx known
df.iat[5,2]="New Zealand"

# %%
df
# Out:
#                    Name  Jersey       Country  Matches  Highest Score
# 0        GOD of Cricket      10         India      664            248
# 1           Virat Kohli      18         India      550            254
# 2  Mahendra Singh Dhoni       7         India      538            224
# 3          Rohit Sharma      45         India      499            264
# 4           Pat Cummins      30     Australia      218             64
# 5            Ben Stokes      55   New Zealand      272            258
# 6        AB De Villiers      17  South Africa      420            278
# 7           Steve Smith      49     Australia      354            239
# 8        Jasprit Bumrah      93         India      211             34
# 9         Hardik Pandya      33         India      224            108

# %%
df.iloc[1,3]
# Out:
# np.int64(550)

# %%
df.iloc[:,0:4]
# Out:
#                    Name  Jersey       Country  Matches
# 0        GOD of Cricket      10         India      664
# 1           Virat Kohli      18         India      550
# 2  Mahendra Singh Dhoni       7         India      538
# 3          Rohit Sharma      45         India      499
# 4           Pat Cummins      30     Australia      218
# 5            Ben Stokes      55   New Zealand      272
# 6        AB De Villiers      17  South Africa      420
# 7           Steve Smith      49     Australia      354
# 8        Jasprit Bumrah      93         India      211
# 9         Hardik Pandya      33         India      224

# %%
df.iloc[:,-1]
# Out:
# 0    248
# 1    254
# 2    224
# 3    264
# 4     64
# 5    258
# 6    278
# 7    239
# 8     34
# 9    108
# Name: Highest Score, dtype: int64

# %%
df
# Out:
#                    Name  Jersey       Country  Matches  Highest Score
# 0        GOD of Cricket      10         India      664            248
# 1           Virat Kohli      18         India      550            254
# 2  Mahendra Singh Dhoni       7         India      538            224
# 3          Rohit Sharma      45         India      499            264
# 4           Pat Cummins      30     Australia      218             64
# 5            Ben Stokes      55   New Zealand      272            258
# 6        AB De Villiers      17  South Africa      420            278
# 7           Steve Smith      49     Australia      354            239
# 8        Jasprit Bumrah      93         India      211             34
# 9         Hardik Pandya      33         India      224            108

# %%
df.iloc[0:3,0:3]
# Out:
#                Name  Jersey Country
# 0  Sachin Tendulkar      10   India
# 1       Virat Kohli      18   India
# 2          MS Dhoni       7   India

# %%
print(df)
# Out:
#                    Name  Jersey       Country  Matches  Highest Score
# 0        GOD of Cricket      10         India      664            248
# 1           Virat Kohli      18         India      550            254
# 2  Mahendra Singh Dhoni       7         India      538            224
# 3          Rohit Sharma      45         India      499            264
# 4           Pat Cummins      30     Australia      218             64
# 5            Ben Stokes      55   New Zealand      272            258
# 6        AB De Villiers      17  South Africa      420            278
# 7           Steve Smith      49     Australia      354            239
# 8        Jasprit Bumrah      93         India      211             34
# 9         Hardik Pandya      33         India      224            108

# %%
df1 = pd.DataFrame({
    "Name":['Sachin Tendulkar', 'Virat Kohli', 'MS Dhoni', 'Rohit Sharma', 'Pat Cummins',
            'Ben Stokes', 'AB De Villiers', 'Steve Smith', 'Jasprit Bumrah', 'Hardik Pandya'],
    "Runs": [34357, 27599, 17266, 19700, 2243, 11080, 20014, 17371, 440, 4248],
    "Matches":[664,550,538,499,218,272,420,354,211,224],
})

# %%
# Adding a new col
# df.insert✅
df1.insert(3,"Average",df1["Runs"]/df1["Matches"])

# %%
print(df1)
# Out:
#                Name   Runs  Matches    Average
# 0  Sachin Tendulkar  34357      664  51.742470
# 1       Virat Kohli  27599      550  50.180000
# 2          MS Dhoni  17266      538  32.092937
# 3      Rohit Sharma  19700      499  39.478958
# 4       Pat Cummins   2243      218  10.288991
# 5        Ben Stokes  11080      272  40.735294
# 6    AB De Villiers  20014      420  47.652381
# 7       Steve Smith  17371      354  49.070621
# 8    Jasprit Bumrah    440      211   2.085308
# 9     Hardik Pandya   4248      224  18.964286

# %%
# Renaming Column
df.rename(columns={"Jersey": "Jersey_No","Country":"Team"}, inplace=True)

# %%
print(df)
# Out:
#                    Name  Jersey_No          Team  Matches  Highest Score
# 0        GOD of Cricket         10         India      664            248
# 1           Virat Kohli         18         India      550            254
# 2  Mahendra Singh Dhoni          7         India      538            224
# 3          Rohit Sharma         45         India      499            264
# 4           Pat Cummins         30     Australia      218             64
# 5            Ben Stokes         55   New Zealand      272            258
# 6        AB De Villiers         17  South Africa      420            278
# 7           Steve Smith         49     Australia      354            239
# 8        Jasprit Bumrah         93         India      211             34
# 9         Hardik Pandya         33         India      224            108

# %%
# Add any particular col
df.insert(1, "Height", [5.41, 5.75, 5.75, 5.75, 6.33, 6.0, 5.92, 5.75, 5.83, 6.0])

# %%
print(df)
# Out:
#                    Name  Height  Jersey_No          Team  Matches  \
# 0        GOD of Cricket    5.41         10         India      664
# 1           Virat Kohli    5.75         18         India      550
# 2  Mahendra Singh Dhoni    5.75          7         India      538
# 3          Rohit Sharma    5.75         45         India      499
# 4           Pat Cummins    6.33         30     Australia      218
# 5            Ben Stokes    6.00         55   New Zealand      272
# 6        AB De Villiers    5.92         17  South Africa      420
# 7           Steve Smith    5.75         49     Australia      354
# 8        Jasprit Bumrah    5.83         93         India      211
# 9         Hardik Pandya    6.00         33         India      224
#
#    Highest Score
# 0            248
# 1            254
# 2            224
# 3            264
# 4             64
# 5            258
# 6            278
# 7            239
# 8             34
# 9            108

# %%
# Remove any single particular column
df.pop("Height")
# Out:
# 0    5.41
# 1    5.75
# 2    5.75
# 3    5.75
# 4    6.33
# 5    6.00
# 6    5.92
# 7    5.75
# 8    5.83
# 9    6.00
# Name: Height, dtype: float64

# %%
# Remove any no of columns
df.drop(columns=["Team","Name"],inplace=True)

# %%
print(df)
# Out:
#    Jersey_No  Matches  Highest Score
# 0         10      664            248
# 1         18      550            254
# 2          7      538            224
# 3         45      499            264
# 4         30      218             64
# 5         55      272            258
# 6         17      420            278
# 7         49      354            239
# 8         93      211             34
# 9         33      224            108

# %%
df = pd.DataFrame({
    "Name":['Sachin Tendulkar', 'Virat Kohli', 'MS Dhoni', 'Rohit Sharma', 'Pat Cummins',
            'Ben Stokes', 'AB De Villiers', 'Steve Smith', 'Jasprit Bumrah', 'Hardik Pandya'],
    "Jersey": [10,18,7,45,30,55,17,49,93,33],
    "Country": ['India', 'India', 'India', 'India', 'Australia', 'England', 'South Africa',
                'Australia', 'India', 'India'],
    "Matches":[664,550,538,499,218,272,420,354,211,224],
    "Highest Score":[248,254,224,264,64,258,278,239,34,108]
})

# %%
df.sort_values(by="Name",inplace=True)

# %%
print(df)
# Out:
#                Name  Jersey       Country  Matches  Highest Score
# 6    AB De Villiers      17  South Africa      420            278
# 5        Ben Stokes      55       England      272            258
# 9     Hardik Pandya      33         India      224            108
# 8    Jasprit Bumrah      93         India      211             34
# 2          MS Dhoni       7         India      538            224
# 4       Pat Cummins      30     Australia      218             64
# 3      Rohit Sharma      45         India      499            264
# 0  Sachin Tendulkar      10         India      664            248
# 7       Steve Smith      49     Australia      354            239
# 1       Virat Kohli      18         India      550            254

# %%
df.sort_values(by="Matches",ascending=False,inplace=True)

# %%
print(df)
# Out:
#                Name  Jersey       Country  Matches  Highest Score
# 0  Sachin Tendulkar      10         India      664            248
# 1       Virat Kohli      18         India      550            254
# 2          MS Dhoni       7         India      538            224
# 3      Rohit Sharma      45         India      499            264
# 6    AB De Villiers      17  South Africa      420            278
# 7       Steve Smith      49     Australia      354            239
# 5        Ben Stokes      55       England      272            258
# 9     Hardik Pandya      33         India      224            108
# 4       Pat Cummins      30     Australia      218             64
# 8    Jasprit Bumrah      93         India      211             34
